# %%
import pandas as pd

# %%
from datetime import datetime, timedelta

# %%
mydf = pd.read_csv('ctm-logs.csv')

# %%
mydf
# Out:
#                                               job_name order_id        folder  \
# 0                   EBIETLBCORE_EMC_SOHD_SOLN_INC_BASE    4g26k   EBIETLBCORE
# 1                EBIETLBCORE_EMC_SOHD_SOLN_GDW_SRC_LRF    4e6h7   EBIETLBCORE
# 2                              EBIETLBCORE_FED_LRF_INC    46m5y   EBIETLBCORE
# 3                EBIETLBCORE_EMC_SOHD_SOLN_GDW_SRC_LRF    4f471   EBIETLBCORE
# 4                EBIETLBCORE_EMC_SOHD_SOLN_GDW_SRC_LRF    47k51   EBIETLBCORE
# ..                                                 ...      ...           ...
# 908  SEBIETLPCORE_GBLSLSPKG_INC_CUST_RESTMNT_EXCPTN...    45qlh   EBIETLPCORE
# 909                SEBIETLPPARTY_SRT_REGN_BI_BUY_POWER    4aex0  EBIETLPPARTY
# 910                SEBIETLPPARTY_SRT_REGN_BI_BUY_POWER    4bdde  EBIETLPPARTY
# 911                SEBIETLPPARTY_SRT_REGN_BI_BUY_POWER    4c9rv  EBIETLPPARTY
# 912  SEBIETLPCORE_GBLSLSPKG_INC_CUST_RESTMNT_EXCPTN...    4h6bd   EBIETLPCORE
#
# ...

# %%
mydf['orderDate'] = pd.to_datetime(mydf['orderDate'], format='%y%m%d')

# %%
mydf['orderDate'] = mydf['orderDate'].dt.strftime('%d-%b-%Y')

# %%
mydf
# Out:
#                                               job_name order_id        folder  \
# 0                   EBIETLBCORE_EMC_SOHD_SOLN_INC_BASE    4g26k   EBIETLBCORE
# 1                EBIETLBCORE_EMC_SOHD_SOLN_GDW_SRC_LRF    4e6h7   EBIETLBCORE
# 2                              EBIETLBCORE_FED_LRF_INC    46m5y   EBIETLBCORE
# 3                EBIETLBCORE_EMC_SOHD_SOLN_GDW_SRC_LRF    4f471   EBIETLBCORE
# 4                EBIETLBCORE_EMC_SOHD_SOLN_GDW_SRC_LRF    47k51   EBIETLBCORE
# ..                                                 ...      ...           ...
# 908  SEBIETLPCORE_GBLSLSPKG_INC_CUST_RESTMNT_EXCPTN...    45qlh   EBIETLPCORE
# 909                SEBIETLPPARTY_SRT_REGN_BI_BUY_POWER    4aex0  EBIETLPPARTY
# 910                SEBIETLPPARTY_SRT_REGN_BI_BUY_POWER    4bdde  EBIETLPPARTY
# 911                SEBIETLPPARTY_SRT_REGN_BI_BUY_POWER    4c9rv  EBIETLPPARTY
# 912  SEBIETLPCORE_GBLSLSPKG_INC_CUST_RESTMNT_EXCPTN...    4h6bd   EBIETLPCORE
#
# ...
